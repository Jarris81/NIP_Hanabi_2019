# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import utils

# %%
stats = utils.load_statistics(os.getcwd()+"/results/adhoc_team_1/logs", iteration_number=2942, verbose=True)[0]
# Out:
# Reading statistics from: /home/jason/Documents/TU/NIP_Hanabi_2019/env/results/adhoc_team_3/logs/log_1382

# %%
### Extract avg return per iteration ###

avg_return = [stats['iter%s' % (i)]['average_return'] for i in range(len(stats.values()))]

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(range(len(stats.keys())),np.ravel(avg_return))
plt.ylabel("Avg. Cards, successfully played")
plt.xlabel("Number of Iterations trained")
plt.title("Rainbow 4Player Self-Play Performance")
fig.show()
# Out:
# /home/jason/.local/lib/python3.5/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
